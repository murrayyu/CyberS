# %%
import glob
import os
pdf_path =r"C:\Users\murra\Desktop\MSBA workshop\UN"

# %%
pdfs = glob.glob("{}/*.pdf".format(pdf_path))

# %%
pdfs
# Out:
# ['C:\\Users\\murra\\Desktop\\MSBA workshop\\UN\\Belgium_20122_N.pdf',
#  'C:\\Users\\murra\\Desktop\\MSBA workshop\\UN\\Belgium_2012N.pdf',
#  'C:\\Users\\murra\\Desktop\\MSBA workshop\\UN\\BosniaHerzegovina_2014N.pdf',
#  'C:\\Users\\murra\\Desktop\\MSBA workshop\\UN\\Brazil_20082N.pdf',
#  'C:\\Users\\murra\\Desktop\\MSBA workshop\\UN\\Croatia CR N.pdf',
#  'C:\\Users\\murra\\Desktop\\MSBA workshop\\UN\\Croatia N.pdf']

# %%
from pdf_extractor import extract_pdf_content

# %%
content0 = extract_pdf_content(pdfs[3])
#content1 = extract_pdf_content(pdfs[1])
#content2 = extract_pdf_content(pdfs[2])
#content3 = extract_pdf_content(pdfs[3])
#content4 = extract_pdf_content(pdfs[4])
#content5 = extract_pdf_content(pdfs[5])
#content6 = extract_pdf_content(pdfs[6])
#content7 = extract_pdf_content(pdfs[7])
#content8 = extract_pdf_content(pdfs[8])
#content9 = extract_pdf_content(pdfs[9])
#content10 = extract_pdf_content(pdfs[10])
#content11 = extract_pdf_content(pdfs[11])
#content12 = extract_pdf_content(pdfs[12])
#content13 = extract_pdf_content(pdfs[13])
#content14 = extract_pdf_content(pdfs[14])
#content15 = extract_pdf_content(pdfs[15])
#content16 = extract_pdf_content(pdfs[16])
#content17 = extract_pdf_content(pdfs[17])
#content18 = extract_pdf_content(pdfs[18])
#content19 = extract_pdf_content(pdfs[19])
#content20 = extract_pdf_content(pdfs[20])

# %%
print(content0)
# Out:
# Presidência da República
#
# Casa Civil
#
# Subchefia para Assuntos Jurídicos
#
#
#
# DECRETO Nº 6.703, DE 18 DE DEZEMBRO DE 2008.
#
#  Aprova a Estratégia Nacional de Defesa, e dá outras
# providências.
#
#
#
#
#
# O PRESIDENTE DA REPÚBLICA, no uso da atribuição que lhe confere o art. 84, inciso VI, alínea
# “a”,  da  Constituição,  e  tendo  em  vista  o  disposto  no  Decreto  de  6  de  setembro  de  2007,  que  institui  o
# Comitê Ministerial de Formulação da Estratégia Nacional de Defesa,
#
# DECRETA:
#
# Art. 1o  Fica aprovada a Estratégia Nacional de Defesa anexa a este Decreto.
#
# Art. 2o  Os  órgãos  e  entidades  da  administração  pública  federal  deverão  considerar,  em  seus
#
# planejamentos, ações que concorram para fortalecer a Defesa Nacional.
#
# Art. 3o  Este Decreto entra em vigor na data de sua publicação.
#
# Brasília, 18 de dezembro de 2008; 187o da Independência e 120o da República.
#
# LUIZ INÁCIO LULA DA SILVA
# Nelson Jobim
# Roberto Mangabeira Unger
# ...

# %%
text_file = open("Jamaica.txt", "w")
text_file.write(content15)
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-96-ebc9ccfcc4f4> in <module>()
#       1 text_file = open("Jamaica.txt", "w")
# ----> 2 text_file.write(content15)
#       3 text_file.close()
#
# C:\Users\murra\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\ufb01' in position 19916: character maps to <undefined>

# %%
text_file = open("Japan.txt", "w")
text_file.write(content16)
text_file.close()

# %%
text_file = open("Jordan.txt", "w")
text_file.write(content17)
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-98-2932186c6259> in <module>()
#       1 text_file = open("Jordan.txt", "w")
# ----> 2 text_file.write(content17)
#       3 text_file.close()
#
# C:\Users\murra\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\uf0b7' in position 17452: character maps to <undefined>

# %%
text_file = open("Kenya.txt", "w")
text_file.write(content18)
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-99-65ca1c58e75b> in <module>()
#       1 text_file = open("Kenya.txt", "w")
# ----> 2 text_file.write(content18)
#       3 text_file.close()
#
# C:\Users\murra\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u25a0' in position 14159: character maps to <undefined>

# %%
text_file = open("Korea_RepublicOf.txt", "w")
text_file.write(content19)
text_file.close()

# %%
text_file = open("Latvia.txt", "w")
text_file.write(content20)
text_file.close()

# %%
text_file = open("India.txt", "w")
text_file.write(content11)
text_file.close()

# %%
text_file = open("Ireland.txt", "w")
text_file.write(content12)
text_file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-85-35fd222cb6a0> in <module>()
#       1 text_file = open("Ireland.txt", "w")
# ----> 2 text_file.write(content12)
#       3 text_file.close()
#
# C:\Users\murra\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\uf0b7' in position 10935: character maps to <undefined>

# %%
text_file = open("Israel.txt", "w")
text_file.write(content13)
text_file.close()
